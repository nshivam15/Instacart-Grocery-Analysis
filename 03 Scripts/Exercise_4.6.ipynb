# %% [markdown]
# #### Exercise 4.6 Merging Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Creating string of project folder.

path = r'/Users/nautis1/data_project/09-2025-Instacart-Basket-Analysis/Instacart Basket Analysis'

# %%
# Defining "df" to produce necessary data to identify column names.

df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_cleaned.csv'), index_col =  0)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'product_cleaned.csv'), index_col =  False)

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col =  False)

# %%
#check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#merge the dataframe
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator= True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  customer_first_order  product_id  \
# 0                     NaN                  True         196
# 1                     NaN                  True       14084
# 2                     NaN                  True       12427
# 3                     NaN                  True       26088
# 4                     NaN                  True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_merged_large.shape
# Out:
# (32434489, 12)

# %% [markdown]
# #### Exporting data in pkl format

# %%
#export data to pickle
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
