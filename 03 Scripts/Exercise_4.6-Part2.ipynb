# %% [markdown]
# #### Exercise 4.6 Merging Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Creating string of project folder.

path = r'/Users/nautis1/data_project/09-2025-Instacart-Basket-Analysis/Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'product_cleaned.csv'), index_col =  0)

# %%
#importing orders_products_combined dataframe from the pickle file
orders_products_combined = pd.read_pickle(os.path.join(path, '02 data' , 'prepared data' , 'orders_products_combined.pkl'))

# %%
#check the dimension
orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
#check the products df
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#check the combined df
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  customer_first_order  product_id  \
# 0                     NaN                  True         196
# 1                     NaN                  True       14084
# 2                     NaN                  True       12427
# 3                     NaN                  True       26088
# 4                     NaN                  True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %% [markdown]
# #### Task 5

# %% [markdown]
# The best way to merge these 2 dataframes will be using product_id column.

# %% [markdown]
# #### I need drop merge column so that we can have the new merge column this time

# %%
orders_products_combined = orders_products_combined.drop(columns= ['_merge'])

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  customer_first_order  product_id  \
# 0                     NaN                  True         196
# 1                     NaN                  True       14084
# 2                     NaN                  True       12427
# 3                     NaN                  True       26088
# 4                     NaN                  True       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# ...

# %%
df_ords_prods_merge = df_prods.merge(orders_products_combined, on = 'product_id', indicator = True)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
# ...

# %% [markdown]
# #### Task 6

# %%
#checking the result of merge using merge flag
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### Exporting data in pkl format

# %% [markdown]
# #### Task 7

# %%
# Export data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
